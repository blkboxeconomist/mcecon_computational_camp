# %% [markdown]
# # Homework 05 — Python basics
#
# **Goal.** Exercise the basic types, arithmetic, strings, and booleans.
# Don't use lists, dictionaries, or loops — we haven't covered those yet.
#
# Fill in each `# TODO` cell, run it, and make sure the output matches the
# expected result.

# %% [markdown]
# ## Problem 1 — Compound interest, one step
#
# Given a principal and an annual interest rate, compute the balance after
# one year. Use f-string formatting to print the result to two decimal
# places.
#
# Expected output: `After 1 year: $1050.00`

# %%
principal = 1000.0
rate = 0.05

# TODO: compute the balance after one year and print it

# %% [markdown]
# ## Problem 2 — Units conversion
#
# Convert 100 Fahrenheit to Celsius. Formula: $C = (F - 32) \cdot \frac{5}{9}$.
# Print both values rounded to one decimal place.

# %%
fahrenheit = 100

# TODO: compute celsius and print "100.0 F = ??.? C"

# %% [markdown]
# ## Problem 3 — Two strings
#
# Given `first_name` and `last_name`, produce:
#
# 1. A `full_name` string `"Last, First"`.
# 2. An `initials` string of the form `"F.L."`.
#
# Print both.

# %%
first_name = "Milton"
last_name = "Friedman"

# TODO: full_name and initials

# %% [markdown]
# ## Problem 4 — A palindrome check
#
# A string is a palindrome if it reads the same forwards and backwards
# (ignoring case). Using only `.lower()` and slicing, assign a boolean
# `is_palindrome` that's `True` for `"Level"` and `False` for `"hello"`.
#
# (Write it so it works for either input.)

# %%
word = "Level"  # try also "hello", "racecar", "Python"

# TODO: is_palindrome
# print(word, "palindrome?", is_palindrome)

# %% [markdown]
# ## Problem 5 — A tax bracket check
#
# Suppose a (fictional) tax rule says: if income is at least \$50,000
# *and* the person is at least 18 years old, they owe a 25% tax. Otherwise
# they owe 10%. Given `income` and `age` variables, use a single boolean
# expression (no `if` yet) to compute `owes_high = True/False`, then
# multiply by the corresponding rate.
#
# *Hint*: Python lets you do `rate = high if owes_high else low`.

# %%
income = 55_000
age = 24

# TODO: owes_high, rate, tax
# print(f"Owes ${tax:,.2f} at rate {rate:.0%}")

# %% [markdown]
# ## Problem 6 — Float trap
#
# Without running it first, predict what the cell below prints.
# Then run it.

# %%
print(0.1 + 0.2 == 0.3)

# %% [markdown]
# **Why was the answer what it was?** Write one or two sentences below.
#
# *Your explanation:*

# %% [markdown]
# ## Submission
#
# Save and upload the executed notebook.
