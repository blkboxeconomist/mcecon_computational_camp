# %% [markdown]
# # Homework 01 — Verifying your setup
#
# **Due:** before next week's lecture.
#
# **Goal.** Prove that you installed `uv`, Python, an editor, and Jupyter,
# and that you can run code inside a project environment.
#
# You will:
#
# 1. Install `uv` and use it to install Python 3.12.
# 2. Create a project called `camp-sandbox`.
# 3. Add `ipykernel` and `jupyterlab` as dependencies.
# 4. Launch this homework notebook inside that project and run every cell.
# 5. Answer a few short reflection questions.
#
# Submit the executed `.ipynb` with all outputs visible.

# %% [markdown]
# ## Problem 1 — `uv` version
#
# The cell below uses a shell command (the `!` prefix runs a shell command
# inside Jupyter) to print your `uv` version. Run it. If it errors,
# something is wrong with step 1 of the install.

# %%
# !uv --version

# %% [markdown]
# ## Problem 2 — Which Python am I running?
#
# Jupyter is launched from a `uv` environment. Confirm that the Python you're
# running inside the kernel is the 3.12 you installed.

# %%
import sys

print("Python executable:", sys.executable)
print("Python version:", sys.version.split()[0])

# %% [markdown]
# **Write your answer** in the cell below: does the `executable` path
# above contain `.venv`? If yes, you're correctly running inside the project
# environment. If no, something went wrong — most commonly, Jupyter was
# launched outside `uv run`.

# %% [markdown]
# *Your answer here (double-click to edit this markdown cell).*

# %% [markdown]
# ## Problem 3 — Adding a dependency
#
# From your terminal, in the `camp-sandbox` directory, run:
#
# ```sh
# uv add rich
# ```
#
# Then in the cell below, import `rich` and use it to print something. If the
# import works, you've successfully added and used a dependency.

# %%
from rich import print as rprint

rprint("[bold green]Homework 1 is almost done![/bold green]")

# %% [markdown]
# ## Problem 4 — A tiny bit of Python
#
# Without running anything yet, **read** the following cell and write down
# (in the markdown cell that follows it) what you expect the final value of
# `balance` to be after all iterations. Then run the cell and see if you were
# right.

# %%
principal = 1000.0
rate = 0.05
years = 3

balance = principal
for year in range(1, years + 1):
    balance = balance * (1 + rate)

print(f"final balance: ${balance:,.2f}")

# %% [markdown]
# *Your prediction here.*
#
# *After running the cell, did your prediction match? If not, what surprised
# you?*

# %% [markdown]
# ## Problem 5 — Reflection
#
# Answer each in one or two sentences.
#
# 1. What's one thing about `uv` that felt unfamiliar compared to tools you
#    already know (if any)?
# 2. Did any step of the setup fail? How did you diagnose and fix it?
# 3. Which editor did you choose, and why?
#
# *Your answers here.*

# %% [markdown]
# ## Submission
#
# Make sure every code cell above has been **run** and its output is visible.
# Save the notebook, then upload it to the course portal by the deadline.
