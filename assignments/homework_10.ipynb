# %% [markdown]
# # Homework 10 — LaTeX
#
# **Goal.** Produce a one-page LaTeX document that compiles to PDF.
#
# You'll submit **two files**: the `.tex` source and the compiled `.pdf`.
# The notebook is just a place to paste your final `.tex` and answer a
# couple of reflection questions.

# %% [markdown]
# ## Requirements
#
# Your document must include:
#
# 1. A title, your name, and today's date (`\maketitle`).
# 2. A one-paragraph abstract or introduction.
# 3. **One equation** in an `equation` environment with a label, and at
#    least one sentence that references it with `\eqref{...}`.
# 4. **One table** using `booktabs` (`\toprule`, `\midrule`,
#    `\bottomrule`). Any content — made-up GDP numbers are fine.
# 5. **One figure** (any `.png` / `.pdf` image — you can save one from
#    matplotlib, steal a placeholder, or use a public-domain image).
# 6. **One bibliography entry** cited with `\parencite`.
#
# You can choose the topic. A summary of a paper you read for another
# class is an easy choice.

# %% [markdown]
# ## Problem 1 — Paste your `.tex` source
#
# Paste the full contents of your `main.tex` into the cell below (as a
# markdown code block).
#
# *Your source:*
#
# ```tex
# % paste here
# ```

# %% [markdown]
# ## Problem 2 — Paste your `refs.bib`
#
# ```bibtex
# % paste here
# ```

# %% [markdown]
# ## Problem 3 — Confirm compilation
#
# Run the cell below to confirm your PDF exists. Set `pdf_path` to the
# actual location.

# %%
from pathlib import Path

pdf_path = Path("main.pdf")  # TODO: adjust if needed

if pdf_path.exists():
    size_kb = pdf_path.stat().st_size / 1024
    print(f"Good — {pdf_path} exists ({size_kb:.1f} KB)")
else:
    print(f"MISSING: {pdf_path}")

# %% [markdown]
# ## Problem 4 — Reflection
#
# Answer in 2–3 sentences each:
#
# 1. Which part of the document gave you the most trouble? What error did
#    you see, and how did you fix it?
# 2. Compare LaTeX math to the Markdown math you learned in week 2. When
#    would you choose one over the other?
#
# *Your answers:*

# %% [markdown]
# ## Submission
#
# Upload **three things** to the course portal:
#
# - This notebook (`.ipynb`).
# - Your `.tex` source file.
# - Your compiled `.pdf`.
