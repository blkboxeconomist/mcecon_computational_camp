# %% [markdown]
# # Homework 03 — Command line
#
# **Goal.** Use the shell (via the notebook's `!` escape) to answer
# questions about the computational camp repository itself.
#
# For each problem, write the shell command(s) in the code cell, run them,
# and write your answer in the markdown cell that follows.
#
# > If a command fails, read the error message before retrying. Most errors
# > are typos or missing paths.

# %% [markdown]
# ## Problem 1 — Where are we?
#
# In the cell below, print the current working directory.

# %%
# TODO: print the working directory

# %% [markdown]
# ## Problem 2 — Count lectures
#
# Use `ls` and `wc -l` in a pipe to count the number of directories under
# `lectures/`. Assume this notebook is running in the repo root.

# %%
# TODO: count lecture directories

# %% [markdown]
# *How many lectures are there?*

# %% [markdown]
# ## Problem 3 — Find markdown files
#
# Use `find` (or `ls` with a glob) to list every `README.md` file in the
# repository.

# %%
# TODO: list all README.md files

# %% [markdown]
# ## Problem 4 — Search for a word
#
# Use `grep -r` to find every file in the repo that contains the word
# `homework` (case-insensitive). Pipe to `head` so the output stays short.

# %%
# TODO: recursive case-insensitive grep for "homework"

# %% [markdown]
# ## Problem 5 — A pipeline
#
# Build one command that:
#
# 1. Lists every `.ipynb` file under `lectures/` and `assignments/`,
# 2. Counts how many there are.
#
# (One command, one pipe.)

# %%
# TODO: pipeline counting total .ipynb files

# %% [markdown]
# *Your count:*

# %% [markdown]
# ## Problem 6 — Environment
#
# Print the value of the `SHELL` environment variable and then the first
# three entries on `PATH`. (Hint: `PATH` is colon-separated.)

# %%
# TODO: echo $SHELL and print first three entries of $PATH

# %% [markdown]
# ## Submission
#
# Save and upload the executed notebook.
