# %% [markdown]
# # Homework 06 — Control flow
#
# **Goal.** Exercise `if`, `while`, `for`, `range`, and the classic loop
# patterns. Lists and dicts are still off-limits.

# %% [markdown]
# ## Problem 1 — Sum of squares
#
# Compute $\sum_{i=1}^{20} i^2$ using a `for` loop. Expected: 2870.

# %%
# TODO: total, then print it

# %% [markdown]
# ## Problem 2 — Factorial
#
# Using a `while` loop, compute $7! = 7 \cdot 6 \cdot 5 \cdots 1$.
# Expected: 5040.

# %%
# TODO: factorial with a while loop

# %% [markdown]
# ## Problem 3 — FizzBuzz with a twist
#
# Print 1..30, but:
#
# - Multiples of 3 → `"Fizz"`
# - Multiples of 5 → `"Buzz"`
# - Multiples of both → `"FizzBuzz"`
# - Multiples of 7 → `"Boom"` (added to the others — e.g., 21 → `"FizzBoom"`)

# %%
# TODO: extended FizzBuzz

# %% [markdown]
# ## Problem 4 — Compound interest with a stopping rule
#
# Start with `wealth = 1000`. Each period, add 5% interest. **Stop** when
# `wealth` first exceeds `2000` and print the number of periods it took.
#
# Use a `while` loop.

# %%
# TODO: doubling time

# %% [markdown]
# ## Problem 5 — Primes below 50
#
# Print every prime number strictly less than 50, separated by spaces, on
# a single line. (Use `break` when you find a factor.)

# %%
# TODO: primes

# %% [markdown]
# ## Problem 6 — A string histogram
#
# Count how many times each vowel (`a, e, i, o, u`) appears in a string,
# ignoring case. Print one line per vowel like `a: 3`.
#
# You may **not** use a dictionary yet — do it with five separate counters
# and one loop.

# %%
text = "The great economist measured the elasticity of demand"

# TODO: count vowels with five counters

# %% [markdown]
# ## Submission
#
# Save and upload.
