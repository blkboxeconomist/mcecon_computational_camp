# %% [markdown]
# # Homework 04 — Git
#
# **Goal.** Practice the full Git workflow: commits, branches, a conflict,
# and a pull request.
#
# This homework is mostly **done in your terminal**, not in the notebook.
# Paste the outputs of key commands into the markdown cells below as your
# record.

# %% [markdown]
# ## Problem 1 — Configure Git
#
# Set your `user.name` and `user.email` globally, then run:
#
# ```sh
# git config --list --show-origin | grep user
# ```
#
# **Paste the two lines of output below** (masking your email if you
# prefer).
#
# *Your output:*

# %% [markdown]
# ## Problem 2 — A sandbox repo
#
# In a terminal, run:
#
# ```sh
# mkdir ~/git-hw && cd ~/git-hw
# git init
# echo "# HW 4" > README.md
# echo "Line 1" >> README.md
# git add README.md
# git commit -m "initial commit"
# ```
#
# Then:
#
# ```sh
# git log --oneline
# ```
#
# **Paste the output below.**
#
# *Your output:*

# %% [markdown]
# ## Problem 3 — A second commit
#
# Append a second line to `README.md` and commit the change. **Paste the
# `git log --oneline` output after the second commit.**
#
# *Your output:*

# %% [markdown]
# ## Problem 4 — A branch
#
# Create a branch `add-fact`, add a new file `fact.txt` containing a
# one-line economics fact, commit it, then switch back to `main` and merge.
#
# **Paste the output of `git log --oneline --graph --all` once you're done.**
#
# *Your output:*

# %% [markdown]
# ## Problem 5 — A pull request (GitHub)
#
# 1. On GitHub, create a new empty public repo called `camp-week04`.
# 2. From your local `git-hw`:
#
#    ```sh
#    git remote add origin git@github.com:<your-user>/camp-week04.git
#    git push -u origin main
#    ```
#
# 3. Create a new branch locally (`fix/typo`), edit `README.md` to add any
#    new line, commit, push.
# 4. On GitHub, **open a pull request** from `fix/typo` into `main`.
#
# **Paste the URL of your pull request below.**
#
# *Your PR URL:*

# %% [markdown]
# ## Problem 6 — Reflection
#
# One sentence each:
#
# 1. What did `git status` tell you that was most useful?
# 2. What would you do if you accidentally staged a file you didn't mean to?
# 3. Why is committing often preferable to committing rarely?
#
# *Your answers:*

# %% [markdown]
# ## Submission
#
# Save this notebook and upload. (We'll also look at your pushed GitHub
# repo from problem 5.)
