# %% [markdown]
# # Homework 07 — Collections
#
# **Goal.** Use lists, dicts, sets, tuples, and comprehensions on some
# small "datasets" that live as plain Python literals. No pandas yet.

# %%
# Provided data — do not modify
students = [
    {"name": "Alice", "major": "econ", "gpa": 3.7},
    {"name": "Bob", "major": "math", "gpa": 3.9},
    {"name": "Carol", "major": "econ", "gpa": 3.5},
    {"name": "Dan", "major": "stats", "gpa": 3.8},
    {"name": "Eve", "major": "econ", "gpa": 4.0},
    {"name": "Frank", "major": "math", "gpa": 3.2},
    {"name": "Gina", "major": "cs", "gpa": 3.6},
]

# %% [markdown]
# ## Problem 1 — Majors
#
# Produce a **set** of the unique majors.

# %%
# TODO: majors (set)

# %% [markdown]
# ## Problem 2 — Names list
#
# Produce a **list** of every student's name, sorted alphabetically.

# %%
# TODO: names sorted

# %% [markdown]
# ## Problem 3 — Econ honor roll
#
# Produce a list of the names of students whose `major` is `"econ"` **and**
# whose `gpa` is at least 3.7. Sort by GPA descending.
#
# Hint: `sorted(..., key=..., reverse=True)`.

# %%
# TODO

# %% [markdown]
# ## Problem 4 — Average GPA by major
#
# Produce a **dict** mapping major → average GPA. Round each to two
# decimal places.

# %%
# TODO

# %% [markdown]
# ## Problem 5 — Comprehension warm-up
#
# In one line each, using a comprehension:
#
# 1. A list of the lengths of each student's name.
# 2. A dict mapping name → length of that name.
# 3. A set of the first letters of all majors.

# %%
# TODO (a)

# %%
# TODO (b)

# %%
# TODO (c)

# %% [markdown]
# ## Problem 6 — Zipping
#
# Given the two parallel lists below, produce a dict mapping year → gdp.
# Then compute the year-over-year growth rates into a second dict.
#
# Growth rate for year $t$ is $\frac{gdp_t}{gdp_{t-1}} - 1$. The first
# year has no growth rate; omit it.

# %%
years = [2020, 2021, 2022, 2023]
gdp = [1000, 1050, 1103, 1158]

# TODO: gdp_by_year, growth_by_year

# %% [markdown]
# ## Submission
#
# Save and upload.
