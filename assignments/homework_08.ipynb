# %% [markdown]
# # Homework 08 — Functions
#
# **Goal.** Write, type-hint, document, and informally test a handful of
# pure functions. All functions should have:
#
# - a docstring
# - type hints on parameters and return
# - at least two `assert` lines showing it works for sample inputs

# %% [markdown]
# ## Problem 1 — `celsius_to_fahrenheit`
#
# Write `celsius_to_fahrenheit(c: float) -> float`. Formula:
# $F = C \cdot 9/5 + 32$.

# %%
# TODO: def celsius_to_fahrenheit(...)
# assert ...

# %% [markdown]
# ## Problem 2 — `compound`
#
# `compound(principal, rate, years)` returns the balance after applying
# `rate` per year for `years` periods. All floats; return a float.

# %%
# TODO

# %% [markdown]
# ## Problem 3 — `demean`
#
# `demean(values: list[float]) -> list[float]` — return a new list of
# values shifted so their mean is zero.
#
# Add assertions that check:
# - the returned list has the same length,
# - `sum(demeaned) / len(demeaned)` is approximately zero (use
#   `abs(x) < 1e-9`).

# %%
# TODO

# %% [markdown]
# ## Problem 4 — `running_mean`
#
# `running_mean(values: list[float]) -> list[float]` — return a list where
# the `i`-th entry is the mean of `values[:i+1]`.
#
# Example: `running_mean([2, 4, 6])` → `[2.0, 3.0, 4.0]`.

# %%
# TODO

# %% [markdown]
# ## Problem 5 — `top_n_by`
#
# `top_n_by(records: list[dict], key: str, n: int) -> list[dict]` — return
# the top `n` records from `records` sorted by `key` descending.
#
# Test with the student dataset from homework 7 (reproduced below).

# %%
students = [
    {"name": "Alice", "major": "econ", "gpa": 3.7},
    {"name": "Bob", "major": "math", "gpa": 3.9},
    {"name": "Carol", "major": "econ", "gpa": 3.5},
    {"name": "Dan", "major": "stats", "gpa": 3.8},
    {"name": "Eve", "major": "econ", "gpa": 4.0},
]

# TODO: def top_n_by(...)
# assert top_n_by(students, "gpa", 2)[0]["name"] == "Eve"

# %% [markdown]
# ## Problem 6 — Reflection
#
# For any one of the functions above, answer in 2–3 sentences: what
# property makes it "pure"? What would it look like if it weren't?
#
# *Your answer:*

# %% [markdown]
# ## Submission
#
# Save and upload.
