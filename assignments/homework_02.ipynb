# %% [markdown]
# # Homework 02 — Markdown and Jupyter
#
# **Goal.** Practice Markdown, math, and the notebook editing model.

# %% [markdown]
# ## Problem 1 — Markdown warm-up
#
# Double-click this cell to **edit** it. Replace the bullet list below with
# a short biography of yourself (3–5 lines). Include:
#
# - One **bolded** word
# - One *italic* word
# - A link to your undergraduate institution
# - An unordered list of at least two interests
#
# *Your bio goes here:*
#
# - item 1
# - item 2

# %% [markdown]
# ## Problem 2 — Math
#
# In the cell below, use Markdown + LaTeX to typeset the Cobb-Douglas
# utility function $u(c, l) = c^\alpha l^{1-\alpha}$ and the FOC for
# consumption when facing budget constraint $c + p l = w + I$ (where $I$ is
# non-labor income).
#
# *Your equations here.*

# %% [markdown]
# ## Problem 3 — Table
#
# Produce a Markdown table with three columns — *Year*, *US real GDP growth
# (%)*, *US CPI inflation (%)* — filled in with **approximate** numbers for
# 2021, 2022, and 2023. You don't need to look anything up exactly; the
# point is the table syntax.
#
# *Your table here.*

# %% [markdown]
# ## Problem 4 — Out-of-order execution
#
# Run the next three cells **top to bottom, in order**.

# %%
counter = 0

# %%
counter = counter + 1

# %%
print(counter)

# %% [markdown]
# Now **go back to the middle cell (`counter = counter + 1`) and run it
# two more times.** Then re-run only the `print(counter)` cell.
#
# **Question.** What value does `counter` print? Why would that be
# confusing to someone reading the notebook from top to bottom later?
#
# *Your answer here.*

# %% [markdown]
# ## Problem 5 — Restart and run all
#
# From the menu bar: **Kernel → Restart Kernel and Run All Cells**. Watch
# the outputs re-compute.
#
# **Question.** After the restart-and-run-all, what is the final value of
# `counter`? Explain in one sentence why.
#
# *Your answer here.*

# %% [markdown]
# ## Submission
#
# Save the notebook, make sure every cell's output is present, upload the
# `.ipynb`.
