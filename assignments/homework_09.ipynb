# %% [markdown]
# # Homework 09 — Debugging (with or without AI)
#
# **Goal.** Diagnose and fix a series of broken code cells. Each cell below
# has a bug. Read the traceback, identify the cause, and fix it so the cell
# runs and produces the expected output.
#
# You may use an AI assistant. If you do, **explain in a markdown cell what
# you asked and what you learned** — blindly pasting answers won't teach
# you to debug.

# %% [markdown]
# ## Problem 1 — A typo
#
# Expected output: `49`.

# %%
def sqaure(x):
    return x * x


print(square(7))

# %% [markdown]
# *Explain what went wrong and what you changed:*

# %% [markdown]
# ## Problem 2 — Wrong type
#
# Expected output: `the total is 15`.

# %%
total = "15"
print("the total is " + total + 0)

# %% [markdown]
# *Explain:*

# %% [markdown]
# ## Problem 3 — Off by one
#
# Expected output: the sum of `1 + 2 + ... + 10` = 55.

# %%
total = 0
for i in range(10):
    total += i

print(total)

# %% [markdown]
# *Explain:*

# %% [markdown]
# ## Problem 4 — Dict lookup
#
# Expected output: a count for France of 0.

# %%
populations = {"USA": 330, "CHN": 1400, "DEU": 83}

for country in ("USA", "CHN", "FRA"):
    print(country, populations[country])

# %% [markdown]
# *Explain:*

# %% [markdown]
# ## Problem 5 — Mutable default
#
# Expected: each call's output is `[item]` (just the one item, no
# accumulation).

# %%
def bucket_of(item, bucket=[]):
    bucket.append(item)
    return bucket


print(bucket_of("a"))
print(bucket_of("b"))
print(bucket_of("c"))

# %% [markdown]
# *Explain:*

# %% [markdown]
# ## Problem 6 — Use `try`/`except`
#
# Write a function `safe_divide(a, b)` that returns `a / b` normally and
# returns `None` when `b == 0` (don't raise). Add two assertions that
# demonstrate both cases.

# %%
# TODO: safe_divide + assertions

# %% [markdown]
# ## Problem 7 — A tiny dataclass
#
# Define a `@dataclass` called `Paper` with fields `title: str`,
# `authors: list[str]`, and `year: int`. Add a method `is_recent` that
# returns `True` when `year >= 2020`.
#
# Create one instance and call the method.

# %%
# TODO: dataclass Paper + method + sample instance

# %% [markdown]
# ## Problem 8 — Reflection
#
# If you used an AI assistant on any problem above, describe one moment
# where it helped and one moment where it misled you (or where you had to
# check something it said). If you didn't use one, describe the debugging
# strategy you used on problem 3.
#
# *Your answer:*

# %% [markdown]
# ## Submission
#
# Save and upload.
